# %%
import dotenv
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma

# %%
print("path to env")
from dotenv import load_dotenv, dotenv_values

load_dotenv() 
print (dotenv_values())
# Out:
# path to env
# OrderedDict({'OPENAI_API_KEY': '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', 'Huggingface_API_Token': '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'})

# %%
import pandas as pd

books = pd.read_csv("books_cleaned.csv")

# %%
books
# Out:
#              isbn13      isbn10                                title  \
# 0     9780313309335  0313309337                The Fantastic Vampire
# 1     9780020442608  0020442602       The voyage of the Dawn Treader
# 2     9780719071157  0719071151                  A Farewell to Arms?
# 3     9780373483372  0373483376                  Tallchief for Keeps
# 4     9781904633273  1904633277                         Little Women
# ...             ...         ...                                  ...
# 2593  9780618254118  0618254110                       Queen of Scots
# 2594  9780345441034  0345441036                          Black House
# 2595  9780810954809  081095480X                  The Lighthouse Land
# 2596  9780060777333  0060777338                    The Cat's Pajamas
# 2597  9780764134289  0764134280  American Sign Language The Easy Way
#
#                                                 authors  \
# 0                                     James Craig Holte
# 1                                   Clive Staples Lewis
# 2               Michael Cox;Adrian Guelke;Fiona Stephen
# 3                                           Cait London
# 4                                     Louisa May Alcott
# ...                                                 ...
# 2593                                 John Alexander Guy
# 2594                          Stephen King;Peter Straub
# 2595                                     Adrian McKinty
# 2596                                       Ray Bradbury
# 2597  David A. Stewart;Elizabeth Stewart;Jessalyn Li...
#
#                        categories  \
# 0              Literary Criticism
# 1                Juvenile Fiction
# 2                         History
# 3                         Fiction
# 4                     Family life
# ...                           ...
# 2593                      History
# 2594                      Fiction
# 2595             Juvenile Fiction
# 2596                      Fiction
# 2597  Language Arts & Disciplines
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=mpmrW...
# 1     http://books.google.com/books/content?id=fDD3C...
# 2     http://books.google.com/books/content?id=G5wuw...
# 3     http://books.google.com/books/content?id=Vn8lm...
# 4     http://books.google.com/books/content?id=lH7BZ...
# ...                                                 ...
# 2593  http://books.google.com/books/content?id=PmqqA...
# 2594  http://books.google.com/books/content?id=SdqhE...
# 2595  http://books.google.com/books/content?id=dhRJA...
# 2596  http://books.google.com/books/content?id=Xb6MU...
# 2597  http://books.google.com/books/content?id=QrR4_...
#
#                                             description  published_year  \
# 0     Wherever vampires existed in the imaginations ...          2002.0
# 1     The "Dawn Treader" is the first ship Narnia ha...          1970.0
# 2     Neither naively optimistic nor hopelessley pes...          2006.0
# 3     Everyone in Amen Flats is shocked when prim El...          1997.0
# 4     Timeless in its evocation of idealised family ...          2004.0
# ...                                                 ...             ...
# 2593  A new historian of Mary Queen of Scots draws o...          2004.0
# 2594  A retired Los Angeles homicide detective livin...          2001.0
# 2595  Thirteen-year-old Jamie is overjoyed when a be...          2006.0
# 2596  From the winner of the National Book Foundatio...          2005.0
# 2597  (back cover) ALL THE ESSENTIALS IN ONE CLEAR V...          2006.0
#
#       average_rating  num_pages  ratings_count  \
# 0               0.00      176.0            0.0
# 1               4.09      216.0         2869.0
# 2               4.33      624.0            0.0
# 3               4.22      296.0           64.0
# 4               4.06      327.0           74.0
# ...              ...        ...            ...
# 2593            3.95      581.0         1637.0
# 2594            4.00      659.0          368.0
# 2595            3.60      372.0          839.0
# 2596            3.73      234.0         1316.0
# 2597            3.72      480.0           33.0
#
#                                      title_and_subtitle  \
# 0     The Fantastic Vampire: Studies in the Children...
# 1                        The voyage of the Dawn Treader
# 2     A Farewell to Arms?: Beyond the Good Friday Ag...
# 3                                   Tallchief for Keeps
# 4                                          Little Women
# ...                                                 ...
# 2593       Queen of Scots: The True Life of Mary Stuart
# 2594                                        Black House
# 2595                                The Lighthouse Land
# 2596                         The Cat's Pajamas: Stories
# 2597                American Sign Language The Easy Way
#
#                                      tagged_description
# 0     9780313309335 Wherever vampires existed in the...
# 1     9780020442608 The "Dawn Treader" is the first ...
# 2     9780719071157 Neither naively optimistic nor h...
# 3     9780373483372 Everyone in Amen Flats is shocke...
# 4     9781904633273 Timeless in its evocation of ide...
# ...                                                 ...
# 2593  9780618254118 A new historian of Mary Queen of...
# 2594  9780345441034 A retired Los Angeles homicide d...
# 2595  9780810954809 Thirteen-year-old Jamie is overj...
# 2596  9780060777333 From the winner of the National ...
# 2597  9780764134289 (back cover) ALL THE ESSENTIALS ...
#
# [2598 rows x 13 columns]

# %%
import os
print(os.getcwd())
print(os.path.exists("tagged_description.txt"))
# Out:
# C:\Users\Ananya\OneDrive\Onedrive\Desktop\2025 Files\Semester 2\Machine Learning\Book-Recommendation
# True

# %%
with open("tagged_description.txt", "r", encoding="utf-8") as f:
    print(f.readline())
# Out:
# "9780313309335 Wherever vampires existed in the imaginations of different peoples, they adapted themselves to the customs of the local culture. In The Vampyre (1819), John Polidori introduced Lord Ruthven and established the vampire craze of the 19th century that resulted in a flood of German vampire poetry, French vampire drama, and British vampire fiction. That tradition culminated in Bram Stoker's Dracula (1897), which fixed the character of the Transylvanian nobleman firmly in the public imagination. The contributors to this volume examine representations of the vampire in fiction, film, folklore, and popular culture. While some look at Stoker and the early literary vampire, others study the works of contemporary writers, such as Anne Rice and Chelsea Quinn Yarbro, vampirism as a metaphor for AIDS, and racial issues in such films as Blacula and Vampire in Brooklyn."

# %%
books["tagged_description"].to_csv("tagged_description.txt",
                                   lineterminator = "\n",
                                   index = False,
                                   header = False)

# %%
import os
path = os.path.abspath("tagged_description.txt")
raw_documents = TextLoader(path, encoding="utf-8").load()
text_splitter = CharacterTextSplitter(chunk_size=1, chunk_overlap=0, separator="\n")
documents = text_splitter.split_documents(raw_documents)
# Out:
# Created a chunk of size 882, which is longer than the specified 1
# Created a chunk of size 389, which is longer than the specified 1
# Created a chunk of size 254, which is longer than the specified 1
# Created a chunk of size 236, which is longer than the specified 1
# Created a chunk of size 855, which is longer than the specified 1
# Created a chunk of size 1299, which is longer than the specified 1
# Created a chunk of size 379, which is longer than the specified 1
# Created a chunk of size 194, which is longer than the specified 1
# Created a chunk of size 489, which is longer than the specified 1
# Created a chunk of size 215, which is longer than the specified 1
# Created a chunk of size 396, which is longer than the specified 1
# Created a chunk of size 244, which is longer than the specified 1
# Created a chunk of size 201, which is longer than the specified 1
# Created a chunk of size 236, which is longer than the specified 1
# Created a chunk of size 177, which is longer than the specified 1
# Created a chunk of size 903, which is longer than the specified 1
# Created a chunk of size 453, which is longer than the specified 1
# Created a chunk of size 242, which is longer than the specified 1
# Created a chunk of size 550, which is longer than the specified 1
# Created a chunk of size 308, which is longer than the specified 1
# Created a chunk of size 353, which is longer than the specified 1
# Created a chunk of size 199, which is longer than the specified 1
# Created a chunk of size 184, which is longer than the specified 1
# Created a chunk of size 260, which is longer than the specified 1
# Created a chunk of size 1042, which is longer than the specified 1
# Created a chunk of size 472, which is longer than the specified 1
# Created a chunk of size 578, which is longer than the specified 1
# Created a chunk of size 1325, which is longer than the specified 1
# Created a chunk of size 239, which is longer than the specified 1
# Created a chunk of size 228, which is longer than the specified 1
# Created a chunk of size 235, which is longer than the specified 1
# Created a chunk of size 409, which is longer than the specified 1
# Created a chunk of size 172, which is longer than the specified 1
# Created a chunk of size 263, which is longer than the specified 1
# Created a chunk of size 213, which is longer than the specified 1
# Created a chunk of size 256, which is longer than the specified 1
# Created a chunk of size 187, which is longer than the specified 1
# Created a chunk of size 898, which is longer than the specified 1
# Created a chunk of size 216, which is longer than the specified 1
# Created a chunk of size 751, which is longer than the specified 1
# Created a chunk of size 926, which is longer than the specified 1
# Created a chunk of size 621, which is longer than the specified 1
# Created a chunk of size 1048, which is longer than the specified 1
# Created a chunk of size 271, which is longer than the specified 1
# Created a chunk of size 256, which is longer than the specified 1
# Created a chunk of size 327, which is longer than the specified 1
# Created a chunk of size 246, which is longer than the specified 1
# Created a chunk of size 209, which is longer than the specified 1
# Created a chunk of size 1482, which is longer than the specified 1
# Created a chunk of size 248, which is longer than the specified 1
# Created a chunk of size 1101, which is longer than the specified 1
# Created a chunk of size 316, which is longer than the specified 1
# Created a chunk of size 305, which is longer than the specified 1
# Created a chunk of size 906, which is longer than the specified 1
# Created a chunk of size 237, which is longer than the specified 1
# Created a chunk of size 406, which is longer than the specified 1
# Created a chunk of size 1454, which is longer than the specified 1
# Created a chunk of size 212, which is longer than the specified 1
# Created a chunk of size 465, which is longer than the specified 1
# Created a chunk of size 244, which is longer than the specified 1
# Created a chunk of size 331, which is longer than the specified 1
# Created a chunk of size 649, which is longer than the specified 1
# Created a chunk of size 425, which is longer than the specified 1
# Created a chunk of size 283, which is longer than the specified 1
# Created a chunk of size 684, which is longer than the specified 1
# Created a chunk of size 884, which is longer than the specified 1
# Created a chunk of size 1110, which is longer than the specified 1
# Created a chunk of size 181, which is longer than the specified 1
# Created a chunk of size 1471, which is longer than the specified 1
# Created a chunk of size 713, which is longer than the specified 1
# Created a chunk of size 1963, which is longer than the specified 1
# Created a chunk of size 196, which is longer than the specified 1
# Created a chunk of size 386, which is longer than the specified 1
# Created a chunk of size 227, which is longer than the specified 1
# Created a chunk of size 373, which is longer than the specified 1
# Created a chunk of size 357, which is longer than the specified 1
# Created a chunk of size 299, which is longer than the specified 1
# Created a chunk of size 361, which is longer than the specified 1
# Created a chunk of size 359, which is longer than the specified 1
# Created a chunk of size 351, which is longer than the specified 1
# Created a chunk of size 1027, which is longer than the specified 1
# Created a chunk of size 280, which is longer than the specified 1
# Created a chunk of size 1657, which is longer than the specified 1
# Created a chunk of size 397, which is longer than the specified 1
# Created a chunk of size 445, which is longer than the specified 1
# Created a chunk of size 280, which is longer than the specified 1
# Created a chunk of size 306, which is longer than the specified 1
# Created a chunk of size 846, which is longer than the specified 1
# Created a chunk of size 298, which is longer than the specified 1
# Created a chunk of size 770, which is longer than the specified 1
# Created a chunk of size 846, which is longer than the specified 1
# Created a chunk of size 185, which is longer than the specified 1
# Created a chunk of size 194, which is longer than the specified 1
# Created a chunk of size 232, which is longer than the specified 1
# Created a chunk of size 436, which is longer than the specified 1
# Created a chunk of size 371, which is longer than the specified 1
# Created a chunk of size 2347, which is longer than the specified 1
# Created a chunk of size 337, which is longer than the specified 1
# Created a chunk of size 349, which is longer than the specified 1
# Created a chunk of size 309, which is longer than the specified 1
# Created a chunk of size 758, which is longer than the specified 1
# Created a chunk of size 286, which is longer than the specified 1
# Created a chunk of size 307, which is longer than the specified 1
# Created a chunk of size 185, which is longer than the specified 1
# Created a chunk of size 553, which is longer than the specified 1
# Created a chunk of size 362, which is longer than the specified 1
# Created a chunk of size 208, which is longer than the specified 1
# Created a chunk of size 356, which is longer than the specified 1
# Created a chunk of size 1267, which is longer than the specified 1
# Created a chunk of size 165, which is longer than the specified 1
# Created a chunk of size 190, which is longer than the specified 1
# Created a chunk of size 282, which is longer than the specified 1
# Created a chunk of size 247, which is longer than the specified 1
# Created a chunk of size 1534, which is longer than the specified 1
# Created a chunk of size 226, which is longer than the specified 1
# Created a chunk of size 517, which is longer than the specified 1
# Created a chunk of size 264, which is longer than the specified 1
# Created a chunk of size 255, which is longer than the specified 1
# Created a chunk of size 666, which is longer than the specified 1
# Created a chunk of size 238, which is longer than the specified 1
# Created a chunk of size 695, which is longer than the specified 1
# Created a chunk of size 558, which is longer than the specified 1
# Created a chunk of size 268, which is longer than the specified 1
# Created a chunk of size 154, which is longer than the specified 1
# Created a chunk of size 1202, which is longer than the specified 1
# Created a chunk of size 258, which is longer than the specified 1
# Created a chunk of size 861, which is longer than the specified 1
# Created a chunk of size 180, which is longer than the specified 1
# Created a chunk of size 1287, which is longer than the specified 1
# Created a chunk of size 249, which is longer than the specified 1
# Created a chunk of size 234, which is longer than the specified 1
# Created a chunk of size 267, which is longer than the specified 1
# Created a chunk of size 389, which is longer than the specified 1
# Created a chunk of size 275, which is longer than the specified 1
# Created a chunk of size 244, which is longer than the specified 1
# Created a chunk of size 371, which is longer than the specified 1
# Created a chunk of size 354, which is longer than the specified 1
# Created a chunk of size 241, which is longer than the specified 1
# Created a chunk of size 230, which is longer than the specified 1
# Created a chunk of size 388, which is longer than the specified 1
# Created a chunk of size 523, which is longer than the specified 1
# Created a chunk of size 880, which is longer than the specified 1
# Created a chunk of size 444, which is longer than the specified 1
# Created a chunk of size 205, which is longer than the specified 1
# Created a chunk of size 683, which is longer than the specified 1
# Created a chunk of size 1001, which is longer than the specified 1
# Created a chunk of size 511, which is longer than the specified 1
# Created a chunk of size 273, which is longer than the specified 1
# Created a chunk of size 714, which is longer than the specified 1
# Created a chunk of size 903, which is longer than the specified 1
# Created a chunk of size 248, which is longer than the specified 1
# Created a chunk of size 784, which is longer than the specified 1
# Created a chunk of size 271, which is longer than the specified 1
# Created a chunk of size 5836, which is longer than the specified 1
# Created a chunk of size 261, which is longer than the specified 1
# Created a chunk of size 600, which is longer than the specified 1
# Created a chunk of size 242, which is longer than the specified 1
# Created a chunk of size 210, which is longer than the specified 1
# Created a chunk of size 266, which is longer than the specified 1
# Created a chunk of size 978, which is longer than the specified 1
# Created a chunk of size 474, which is longer than the specified 1
# Created a chunk of size 547, which is longer than the specified 1
# Created a chunk of size 273, which is longer than the specified 1
# Created a chunk of size 193, which is longer than the specified 1
# Created a chunk of size 522, which is longer than the specified 1
# Created a chunk of size 1002, which is longer than the specified 1
# Created a chunk of size 917, which is longer than the specified 1
# Created a chunk of size 216, which is longer than the specified 1
# Created a chunk of size 388, which is longer than the specified 1
# Created a chunk of size 277, which is longer than the specified 1
# Created a chunk of size 806, which is longer than the specified 1
# Created a chunk of size 243, which is longer than the specified 1
# Created a chunk of size 316, which is longer than the specified 1
# Created a chunk of size 534, which is longer than the specified 1
# Created a chunk of size 643, which is longer than the specified 1
# Created a chunk of size 799, which is longer than the specified 1
# Created a chunk of size 176, which is longer than the specified 1
# Created a chunk of size 204, which is longer than the specified 1
# Created a chunk of size 955, which is longer than the specified 1
# Created a chunk of size 347, which is longer than the specified 1
# Created a chunk of size 250, which is longer than the specified 1
# Created a chunk of size 298, which is longer than the specified 1
# Created a chunk of size 291, which is longer than the specified 1
# Created a chunk of size 274, which is longer than the specified 1
# Created a chunk of size 330, which is longer than the specified 1
# Created a chunk of size 204, which is longer than the specified 1
# Created a chunk of size 216, which is longer than the specified 1
# Created a chunk of size 207, which is longer than the specified 1
# Created a chunk of size 199, which is longer than the specified 1
# Created a chunk of size 709, which is longer than the specified 1
# Created a chunk of size 220, which is longer than the specified 1
# Created a chunk of size 669, which is longer than the specified 1
# Created a chunk of size 1091, which is longer than the specified 1
# Created a chunk of size 201, which is longer than the specified 1
# Created a chunk of size 360, which is longer than the specified 1
# Created a chunk of size 643, which is longer than the specified 1
# Created a chunk of size 981, which is longer than the specified 1
# Created a chunk of size 209, which is longer than the specified 1
# Created a chunk of size 292, which is longer than the specified 1
# Created a chunk of size 180, which is longer than the specified 1
# Created a chunk of size 838, which is longer than the specified 1
# Created a chunk of size 350, which is longer than the specified 1
# Created a chunk of size 346, which is longer than the specified 1
# Created a chunk of size 708, which is longer than the specified 1
# Created a chunk of size 538, which is longer than the specified 1
# Created a chunk of size 269, which is longer than the specified 1
# Created a chunk of size 288, which is longer than the specified 1
# Created a chunk of size 801, which is longer than the specified 1
# Created a chunk of size 190, which is longer than the specified 1
# Created a chunk of size 163, which is longer than the specified 1
# Created a chunk of size 1456, which is longer than the specified 1
# Created a chunk of size 215, which is longer than the specified 1
# Created a chunk of size 234, which is longer than the specified 1
# Created a chunk of size 513, which is longer than the specified 1
# Created a chunk of size 707, which is longer than the specified 1
# Created a chunk of size 221, which is longer than the specified 1
# Created a chunk of size 182, which is longer than the specified 1
# Created a chunk of size 251, which is longer than the specified 1
# Created a chunk of size 965, which is longer than the specified 1
# Created a chunk of size 845, which is longer than the specified 1
# Created a chunk of size 398, which is longer than the specified 1
# Created a chunk of size 218, which is longer than the specified 1
# Created a chunk of size 994, which is longer than the specified 1
# Created a chunk of size 793, which is longer than the specified 1
# Created a chunk of size 1083, which is longer than the specified 1
# Created a chunk of size 246, which is longer than the specified 1
# Created a chunk of size 205, which is longer than the specified 1
# Created a chunk of size 255, which is longer than the specified 1
# Created a chunk of size 906, which is longer than the specified 1
# Created a chunk of size 401, which is longer than the specified 1
# Created a chunk of size 145, which is longer than the specified 1
# Created a chunk of size 167, which is longer than the specified 1
# Created a chunk of size 561, which is longer than the specified 1
# Created a chunk of size 454, which is longer than the specified 1
# Created a chunk of size 840, which is longer than the specified 1
# Created a chunk of size 1443, which is longer than the specified 1
# Created a chunk of size 207, which is longer than the specified 1
# Created a chunk of size 361, which is longer than the specified 1
# Created a chunk of size 226, which is longer than the specified 1
# Created a chunk of size 1286, which is longer than the specified 1
# Created a chunk of size 555, which is longer than the specified 1
# Created a chunk of size 631, which is longer than the specified 1
# Created a chunk of size 1037, which is longer than the specified 1
# Created a chunk of size 672, which is longer than the specified 1
# Created a chunk of size 874, which is longer than the specified 1
# Created a chunk of size 419, which is longer than the specified 1
# Created a chunk of size 362, which is longer than the specified 1
# Created a chunk of size 1354, which is longer than the specified 1
# Created a chunk of size 1382, which is longer than the specified 1
# Created a chunk of size 1248, which is longer than the specified 1
# Created a chunk of size 280, which is longer than the specified 1
# Created a chunk of size 1809, which is longer than the specified 1
# Created a chunk of size 207, which is longer than the specified 1
# Created a chunk of size 250, which is longer than the specified 1
# Created a chunk of size 266, which is longer than the specified 1
# Created a chunk of size 236, which is longer than the specified 1
# Created a chunk of size 854, which is longer than the specified 1
# Created a chunk of size 243, which is longer than the specified 1
# Created a chunk of size 479, which is longer than the specified 1
# Created a chunk of size 269, which is longer than the specified 1
# Created a chunk of size 266, which is longer than the specified 1
# Created a chunk of size 149, which is longer than the specified 1
# Created a chunk of size 879, which is longer than the specified 1
# Created a chunk of size 329, which is longer than the specified 1
# Created a chunk of size 348, which is longer than the specified 1
# Created a chunk of size 192, which is longer than the specified 1
# Created a chunk of size 251, which is longer than the specified 1
# Created a chunk of size 271, which is longer than the specified 1
# Created a chunk of size 1283, which is longer than the specified 1
# Created a chunk of size 233, which is longer than the specified 1
# Created a chunk of size 769, which is longer than the specified 1
# Created a chunk of size 264, which is longer than the specified 1
# Created a chunk of size 198, which is longer than the specified 1
# Created a chunk of size 346, which is longer than the specified 1
# Created a chunk of size 1442, which is longer than the specified 1
# Created a chunk of size 178, which is longer than the specified 1
# Created a chunk of size 234, which is longer than the specified 1
# Created a chunk of size 447, which is longer than the specified 1
# Created a chunk of size 242, which is longer than the specified 1
# Created a chunk of size 208, which is longer than the specified 1
# Created a chunk of size 978, which is longer than the specified 1
# Created a chunk of size 308, which is longer than the specified 1
# Created a chunk of size 1030, which is longer than the specified 1
# Created a chunk of size 985, which is longer than the specified 1
# Created a chunk of size 338, which is longer than the specified 1
# Created a chunk of size 209, which is longer than the specified 1
# Created a chunk of size 407, which is longer than the specified 1
# Created a chunk of size 286, which is longer than the specified 1
# Created a chunk of size 284, which is longer than the specified 1
# Created a chunk of size 1381, which is longer than the specified 1
# Created a chunk of size 264, which is longer than the specified 1
# Created a chunk of size 260, which is longer than the specified 1
# Created a chunk of size 582, which is longer than the specified 1
# Created a chunk of size 211, which is longer than the specified 1
# Created a chunk of size 579, which is longer than the specified 1
# Created a chunk of size 979, which is longer than the specified 1
# Created a chunk of size 724, which is longer than the specified 1
# Created a chunk of size 406, which is longer than the specified 1
# Created a chunk of size 325, which is longer than the specified 1
# Created a chunk of size 250, which is longer than the specified 1
# Created a chunk of size 366, which is longer than the specified 1
# Created a chunk of size 1144, which is longer than the specified 1
# Created a chunk of size 216, which is longer than the specified 1
# Created a chunk of size 465, which is longer than the specified 1
# Created a chunk of size 366, which is longer than the specified 1
# Created a chunk of size 255, which is longer than the specified 1
# Created a chunk of size 201, which is longer than the specified 1
# Created a chunk of size 229, which is longer than the specified 1
# Created a chunk of size 438, which is longer than the specified 1
# Created a chunk of size 1893, which is longer than the specified 1
# Created a chunk of size 1228, which is longer than the specified 1
# Created a chunk of size 242, which is longer than the specified 1
# Created a chunk of size 207, which is longer than the specified 1
# Created a chunk of size 760, which is longer than the specified 1
# Created a chunk of size 176, which is longer than the specified 1
# Created a chunk of size 193, which is longer than the specified 1
# Created a chunk of size 227, which is longer than the specified 1
# Created a chunk of size 164, which is longer than the specified 1
# Created a chunk of size 674, which is longer than the specified 1
# Created a chunk of size 326, which is longer than the specified 1
# Created a chunk of size 727, which is longer than the specified 1
# Created a chunk of size 1054, which is longer than the specified 1
# Created a chunk of size 489, which is longer than the specified 1
# Created a chunk of size 694, which is longer than the specified 1
# Created a chunk of size 587, which is longer than the specified 1
# Created a chunk of size 767, which is longer than the specified 1
# Created a chunk of size 198, which is longer than the specified 1
# Created a chunk of size 409, which is longer than the specified 1
# Created a chunk of size 2616, which is longer than the specified 1
# Created a chunk of size 220, which is longer than the specified 1
# Created a chunk of size 387, which is longer than the specified 1
# Created a chunk of size 691, which is longer than the specified 1
# Created a chunk of size 263, which is longer than the specified 1
# Created a chunk of size 665, which is longer than the specified 1
# Created a chunk of size 952, which is longer than the specified 1
# Created a chunk of size 273, which is longer than the specified 1
# Created a chunk of size 301, which is longer than the specified 1
# Created a chunk of size 1064, which is longer than the specified 1
# Created a chunk of size 258, which is longer than the specified 1
# Created a chunk of size 251, which is longer than the specified 1
# Created a chunk of size 1362, which is longer than the specified 1
# Created a chunk of size 940, which is longer than the specified 1
# Created a chunk of size 658, which is longer than the specified 1
# Created a chunk of size 205, which is longer than the specified 1
# Created a chunk of size 280, which is longer than the specified 1
# Created a chunk of size 380, which is longer than the specified 1
# Created a chunk of size 174, which is longer than the specified 1
# Created a chunk of size 1922, which is longer than the specified 1
# Created a chunk of size 672, which is longer than the specified 1
# Created a chunk of size 1359, which is longer than the specified 1
# Created a chunk of size 214, which is longer than the specified 1
# Created a chunk of size 289, which is longer than the specified 1
# Created a chunk of size 202, which is longer than the specified 1
# Created a chunk of size 297, which is longer than the specified 1
# Created a chunk of size 553, which is longer than the specified 1
# Created a chunk of size 1210, which is longer than the specified 1
# Created a chunk of size 298, which is longer than the specified 1
# Created a chunk of size 524, which is longer than the specified 1
# Created a chunk of size 185, which is longer than the specified 1
# Created a chunk of size 799, which is longer than the specified 1
# Created a chunk of size 194, which is longer than the specified 1
# Created a chunk of size 367, which is longer than the specified 1
# Created a chunk of size 198, which is longer than the specified 1
# Created a chunk of size 760, which is longer than the specified 1
# Created a chunk of size 273, which is longer than the specified 1
# Created a chunk of size 738, which is longer than the specified 1
# Created a chunk of size 256, which is longer than the specified 1
# Created a chunk of size 618, which is longer than the specified 1
# Created a chunk of size 1648, which is longer than the specified 1
# Created a chunk of size 356, which is longer than the specified 1
# Created a chunk of size 480, which is longer than the specified 1
# Created a chunk of size 780, which is longer than the specified 1
# Created a chunk of size 227, which is longer than the specified 1
# Created a chunk of size 272, which is longer than the specified 1
# Created a chunk of size 361, which is longer than the specified 1
# Created a chunk of size 618, which is longer than the specified 1
# Created a chunk of size 250, which is longer than the specified 1
# Created a chunk of size 196, which is longer than the specified 1
# Created a chunk of size 1997, which is longer than the specified 1
# Created a chunk of size 257, which is longer than the specified 1
# Created a chunk of size 250, which is longer than the specified 1
# Created a chunk of size 881, which is longer than the specified 1
# Created a chunk of size 222, which is longer than the specified 1
# Created a chunk of size 276, which is longer than the specified 1
# Created a chunk of size 296, which is longer than the specified 1
# Created a chunk of size 200, which is longer than the specified 1
# Created a chunk of size 297, which is longer than the specified 1
# Created a chunk of size 337, which is longer than the specified 1
# Created a chunk of size 253, which is longer than the specified 1
# Created a chunk of size 279, which is longer than the specified 1
# Created a chunk of size 250, which is longer than the specified 1
# Created a chunk of size 1603, which is longer than the specified 1
# Created a chunk of size 279, which is longer than the specified 1
# Created a chunk of size 157, which is longer than the specified 1
# Created a chunk of size 322, which is longer than the specified 1
# Created a chunk of size 206, which is longer than the specified 1
# Created a chunk of size 1201, which is longer than the specified 1
# Created a chunk of size 1127, which is longer than the specified 1
# Created a chunk of size 279, which is longer than the specified 1
# Created a chunk of size 262, which is longer than the specified 1
# Created a chunk of size 315, which is longer than the specified 1
# Created a chunk of size 996, which is longer than the specified 1
# Created a chunk of size 430, which is longer than the specified 1
# Created a chunk of size 437, which is longer than the specified 1
# Created a chunk of size 1275, which is longer than the specified 1
# Created a chunk of size 315, which is longer than the specified 1
# Created a chunk of size 378, which is longer than the specified 1
# Created a chunk of size 874, which is longer than the specified 1
# Created a chunk of size 497, which is longer than the specified 1
# Created a chunk of size 263, which is longer than the specified 1
# Created a chunk of size 674, which is longer than the specified 1
# Created a chunk of size 217, which is longer than the specified 1
# Created a chunk of size 273, which is longer than the specified 1
# Created a chunk of size 263, which is longer than the specified 1
# Created a chunk of size 211, which is longer than the specified 1
# Created a chunk of size 194, which is longer than the specified 1
# Created a chunk of size 2148, which is longer than the specified 1
# Created a chunk of size 210, which is longer than the specified 1
# Created a chunk of size 826, which is longer than the specified 1
# Created a chunk of size 282, which is longer than the specified 1
# Created a chunk of size 247, which is longer than the specified 1
# Created a chunk of size 141, which is longer than the specified 1
# Created a chunk of size 208, which is longer than the specified 1
# Created a chunk of size 183, which is longer than the specified 1
# Created a chunk of size 1130, which is longer than the specified 1
# Created a chunk of size 229, which is longer than the specified 1
# Created a chunk of size 219, which is longer than the specified 1
# Created a chunk of size 152, which is longer than the specified 1
# Created a chunk of size 193, which is longer than the specified 1
# Created a chunk of size 193, which is longer than the specified 1
# Created a chunk of size 399, which is longer than the specified 1
# Created a chunk of size 351, which is longer than the specified 1
# Created a chunk of size 1167, which is longer than the specified 1
# Created a chunk of size 628, which is longer than the specified 1
# Created a chunk of size 1090, which is longer than the specified 1
# Created a chunk of size 252, which is longer than the specified 1
# Created a chunk of size 365, which is longer than the specified 1
# Created a chunk of size 239, which is longer than the specified 1
# Created a chunk of size 483, which is longer than the specified 1
# Created a chunk of size 473, which is longer than the specified 1
# Created a chunk of size 246, which is longer than the specified 1
# Created a chunk of size 271, which is longer than the specified 1
# Created a chunk of size 277, which is longer than the specified 1
# Created a chunk of size 817, which is longer than the specified 1
# Created a chunk of size 215, which is longer than the specified 1
# Created a chunk of size 251, which is longer than the specified 1
# Created a chunk of size 202, which is longer than the specified 1
# Created a chunk of size 221, which is longer than the specified 1
# Created a chunk of size 1145, which is longer than the specified 1
# Created a chunk of size 293, which is longer than the specified 1
# Created a chunk of size 598, which is longer than the specified 1
# Created a chunk of size 348, which is longer than the specified 1
# Created a chunk of size 712, which is longer than the specified 1
# Created a chunk of size 287, which is longer than the specified 1
# Created a chunk of size 1043, which is longer than the specified 1
# Created a chunk of size 231, which is longer than the specified 1
# Created a chunk of size 406, which is longer than the specified 1
# Created a chunk of size 223, which is longer than the specified 1
# Created a chunk of size 292, which is longer than the specified 1
# Created a chunk of size 188, which is longer than the specified 1
# Created a chunk of size 248, which is longer than the specified 1
# Created a chunk of size 284, which is longer than the specified 1
# Created a chunk of size 1019, which is longer than the specified 1
# Created a chunk of size 1165, which is longer than the specified 1
# Created a chunk of size 614, which is longer than the specified 1
# Created a chunk of size 937, which is longer than the specified 1
# Created a chunk of size 431, which is longer than the specified 1
# Created a chunk of size 618, which is longer than the specified 1
# Created a chunk of size 605, which is longer than the specified 1
# Created a chunk of size 182, which is longer than the specified 1
# Created a chunk of size 265, which is longer than the specified 1
# Created a chunk of size 1201, which is longer than the specified 1
# Created a chunk of size 301, which is longer than the specified 1
# Created a chunk of size 674, which is longer than the specified 1
# Created a chunk of size 273, which is longer than the specified 1
# Created a chunk of size 333, which is longer than the specified 1
# Created a chunk of size 397, which is longer than the specified 1
# Created a chunk of size 483, which is longer than the specified 1
# Created a chunk of size 328, which is longer than the specified 1
# Created a chunk of size 2510, which is longer than the specified 1
# Created a chunk of size 198, which is longer than the specified 1
# Created a chunk of size 171, which is longer than the specified 1
# Created a chunk of size 597, which is longer than the specified 1
# Created a chunk of size 986, which is longer than the specified 1
# Created a chunk of size 509, which is longer than the specified 1
# Created a chunk of size 182, which is longer than the specified 1
# Created a chunk of size 661, which is longer than the specified 1
# Created a chunk of size 1174, which is longer than the specified 1
# Created a chunk of size 541, which is longer than the specified 1
# Created a chunk of size 240, which is longer than the specified 1
# Created a chunk of size 329, which is longer than the specified 1
# Created a chunk of size 177, which is longer than the specified 1
# Created a chunk of size 276, which is longer than the specified 1
# Created a chunk of size 556, which is longer than the specified 1
# Created a chunk of size 1090, which is longer than the specified 1
# Created a chunk of size 1637, which is longer than the specified 1
# Created a chunk of size 324, which is longer than the specified 1
# Created a chunk of size 286, which is longer than the specified 1
# Created a chunk of size 788, which is longer than the specified 1
# Created a chunk of size 214, which is longer than the specified 1
# Created a chunk of size 291, which is longer than the specified 1
# Created a chunk of size 466, which is longer than the specified 1
# Created a chunk of size 1005, which is longer than the specified 1
# Created a chunk of size 387, which is longer than the specified 1
# Created a chunk of size 1689, which is longer than the specified 1
# Created a chunk of size 302, which is longer than the specified 1
# Created a chunk of size 259, which is longer than the specified 1
# Created a chunk of size 2122, which is longer than the specified 1
# Created a chunk of size 275, which is longer than the specified 1
# Created a chunk of size 354, which is longer than the specified 1
# Created a chunk of size 850, which is longer than the specified 1
# Created a chunk of size 177, which is longer than the specified 1
# Created a chunk of size 987, which is longer than the specified 1
# Created a chunk of size 225, which is longer than the specified 1
# Created a chunk of size 376, which is longer than the specified 1
# Created a chunk of size 220, which is longer than the specified 1
# Created a chunk of size 229, which is longer than the specified 1
# Created a chunk of size 249, which is longer than the specified 1
# Created a chunk of size 181, which is longer than the specified 1
# Created a chunk of size 663, which is longer than the specified 1
# Created a chunk of size 199, which is longer than the specified 1
# Created a chunk of size 368, which is longer than the specified 1
# Created a chunk of size 375, which is longer than the specified 1
# Created a chunk of size 203, which is longer than the specified 1
# Created a chunk of size 897, which is longer than the specified 1
# Created a chunk of size 292, which is longer than the specified 1
# Created a chunk of size 250, which is longer than the specified 1
# Created a chunk of size 248, which is longer than the specified 1
# Created a chunk of size 296, which is longer than the specified 1
# Created a chunk of size 742, which is longer than the specified 1
# Created a chunk of size 334, which is longer than the specified 1
# Created a chunk of size 759, which is longer than the specified 1
# Created a chunk of size 998, which is longer than the specified 1
# Created a chunk of size 260, which is longer than the specified 1
# Created a chunk of size 431, which is longer than the specified 1
# Created a chunk of size 213, which is longer than the specified 1
# Created a chunk of size 260, which is longer than the specified 1
# Created a chunk of size 239, which is longer than the specified 1
# Created a chunk of size 460, which is longer than the specified 1
# Created a chunk of size 193, which is longer than the specified 1
# Created a chunk of size 1175, which is longer than the specified 1
# Created a chunk of size 182, which is longer than the specified 1
# Created a chunk of size 251, which is longer than the specified 1
# Created a chunk of size 224, which is longer than the specified 1
# Created a chunk of size 216, which is longer than the specified 1
# Created a chunk of size 520, which is longer than the specified 1
# Created a chunk of size 688, which is longer than the specified 1
# Created a chunk of size 323, which is longer than the specified 1
# Created a chunk of size 216, which is longer than the specified 1
# Created a chunk of size 237, which is longer than the specified 1
# Created a chunk of size 978, which is longer than the specified 1
# Created a chunk of size 196, which is longer than the specified 1
# Created a chunk of size 240, which is longer than the specified 1
# Created a chunk of size 1364, which is longer than the specified 1
# Created a chunk of size 234, which is longer than the specified 1
# Created a chunk of size 181, which is longer than the specified 1
# Created a chunk of size 281, which is longer than the specified 1
# Created a chunk of size 364, which is longer than the specified 1
# Created a chunk of size 1265, which is longer than the specified 1
# Created a chunk of size 1285, which is longer than the specified 1
# Created a chunk of size 811, which is longer than the specified 1
# Created a chunk of size 280, which is longer than the specified 1
# Created a chunk of size 261, which is longer than the specified 1
# Created a chunk of size 217, which is longer than the specified 1
# Created a chunk of size 252, which is longer than the specified 1
# Created a chunk of size 527, which is longer than the specified 1
# Created a chunk of size 485, which is longer than the specified 1
# Created a chunk of size 2942, which is longer than the specified 1
# Created a chunk of size 849, which is longer than the specified 1
# Created a chunk of size 2299, which is longer than the specified 1
# Created a chunk of size 969, which is longer than the specified 1
# Created a chunk of size 313, which is longer than the specified 1
# Created a chunk of size 195, which is longer than the specified 1
# Created a chunk of size 693, which is longer than the specified 1
# Created a chunk of size 715, which is longer than the specified 1
# Created a chunk of size 288, which is longer than the specified 1
# Created a chunk of size 901, which is longer than the specified 1
# Created a chunk of size 1269, which is longer than the specified 1
# Created a chunk of size 637, which is longer than the specified 1
# Created a chunk of size 258, which is longer than the specified 1
# Created a chunk of size 266, which is longer than the specified 1
# Created a chunk of size 759, which is longer than the specified 1
# Created a chunk of size 176, which is longer than the specified 1
# Created a chunk of size 251, which is longer than the specified 1
# Created a chunk of size 430, which is longer than the specified 1
# Created a chunk of size 394, which is longer than the specified 1
# Created a chunk of size 761, which is longer than the specified 1
# Created a chunk of size 228, which is longer than the specified 1
# Created a chunk of size 258, which is longer than the specified 1
# Created a chunk of size 1179, which is longer than the specified 1
# Created a chunk of size 218, which is longer than the specified 1
# Created a chunk of size 438, which is longer than the specified 1
# Created a chunk of size 309, which is longer than the specified 1
# Created a chunk of size 197, which is longer than the specified 1
# Created a chunk of size 305, which is longer than the specified 1
# Created a chunk of size 360, which is longer than the specified 1
# Created a chunk of size 338, which is longer than the specified 1
# Created a chunk of size 408, which is longer than the specified 1
# Created a chunk of size 811, which is longer than the specified 1
# Created a chunk of size 272, which is longer than the specified 1
# Created a chunk of size 191, which is longer than the specified 1
# Created a chunk of size 272, which is longer than the specified 1
# Created a chunk of size 192, which is longer than the specified 1
# Created a chunk of size 572, which is longer than the specified 1
# Created a chunk of size 197, which is longer than the specified 1
# Created a chunk of size 448, which is longer than the specified 1
# Created a chunk of size 211, which is longer than the specified 1
# Created a chunk of size 275, which is longer than the specified 1
# Created a chunk of size 905, which is longer than the specified 1
# Created a chunk of size 801, which is longer than the specified 1
# Created a chunk of size 224, which is longer than the specified 1
# Created a chunk of size 1311, which is longer than the specified 1
# Created a chunk of size 304, which is longer than the specified 1
# Created a chunk of size 257, which is longer than the specified 1
# Created a chunk of size 213, which is longer than the specified 1
# Created a chunk of size 378, which is longer than the specified 1
# Created a chunk of size 247, which is longer than the specified 1
# Created a chunk of size 340, which is longer than the specified 1
# Created a chunk of size 174, which is longer than the specified 1
# Created a chunk of size 818, which is longer than the specified 1
# Created a chunk of size 260, which is longer than the specified 1
# Created a chunk of size 180, which is longer than the specified 1
# Created a chunk of size 341, which is longer than the specified 1
# Created a chunk of size 207, which is longer than the specified 1
# Created a chunk of size 279, which is longer than the specified 1
# Created a chunk of size 283, which is longer than the specified 1
# Created a chunk of size 534, which is longer than the specified 1
# Created a chunk of size 234, which is longer than the specified 1
# Created a chunk of size 359, which is longer than the specified 1
# Created a chunk of size 467, which is longer than the specified 1
# Created a chunk of size 958, which is longer than the specified 1
# Created a chunk of size 255, which is longer than the specified 1
# Created a chunk of size 996, which is longer than the specified 1
# Created a chunk of size 386, which is longer than the specified 1
# Created a chunk of size 238, which is longer than the specified 1
# Created a chunk of size 187, which is longer than the specified 1
# Created a chunk of size 990, which is longer than the specified 1
# Created a chunk of size 633, which is longer than the specified 1
# Created a chunk of size 1372, which is longer than the specified 1
# Created a chunk of size 973, which is longer than the specified 1
# Created a chunk of size 1095, which is longer than the specified 1
# Created a chunk of size 759, which is longer than the specified 1
# Created a chunk of size 558, which is longer than the specified 1
# Created a chunk of size 194, which is longer than the specified 1
# Created a chunk of size 574, which is longer than the specified 1
# Created a chunk of size 278, which is longer than the specified 1
# Created a chunk of size 237, which is longer than the specified 1
# Created a chunk of size 313, which is longer than the specified 1
# Created a chunk of size 913, which is longer than the specified 1
# Created a chunk of size 176, which is longer than the specified 1
# Created a chunk of size 228, which is longer than the specified 1
# Created a chunk of size 305, which is longer than the specified 1
# Created a chunk of size 244, which is longer than the specified 1
# Created a chunk of size 214, which is longer than the specified 1
# Created a chunk of size 149, which is longer than the specified 1
# Created a chunk of size 228, which is longer than the specified 1
# Created a chunk of size 312, which is longer than the specified 1
# Created a chunk of size 496, which is longer than the specified 1
# Created a chunk of size 385, which is longer than the specified 1
# Created a chunk of size 652, which is longer than the specified 1
# Created a chunk of size 364, which is longer than the specified 1
# Created a chunk of size 678, which is longer than the specified 1
# Created a chunk of size 1776, which is longer than the specified 1
# Created a chunk of size 372, which is longer than the specified 1
# Created a chunk of size 2869, which is longer than the specified 1
# Created a chunk of size 303, which is longer than the specified 1
# Created a chunk of size 735, which is longer than the specified 1
# Created a chunk of size 334, which is longer than the specified 1
# Created a chunk of size 260, which is longer than the specified 1
# Created a chunk of size 220, which is longer than the specified 1
# Created a chunk of size 1320, which is longer than the specified 1
# Created a chunk of size 1116, which is longer than the specified 1
# Created a chunk of size 478, which is longer than the specified 1
# Created a chunk of size 213, which is longer than the specified 1
# Created a chunk of size 1044, which is longer than the specified 1
# Created a chunk of size 1753, which is longer than the specified 1
# Created a chunk of size 190, which is longer than the specified 1
# Created a chunk of size 839, which is longer than the specified 1
# Created a chunk of size 202, which is longer than the specified 1
# Created a chunk of size 261, which is longer than the specified 1
# Created a chunk of size 188, which is longer than the specified 1
# Created a chunk of size 302, which is longer than the specified 1
# Created a chunk of size 204, which is longer than the specified 1
# Created a chunk of size 1510, which is longer than the specified 1
# Created a chunk of size 251, which is longer than the specified 1
# Created a chunk of size 258, which is longer than the specified 1
# Created a chunk of size 339, which is longer than the specified 1
# Created a chunk of size 182, which is longer than the specified 1
# Created a chunk of size 237, which is longer than the specified 1
# Created a chunk of size 204, which is longer than the specified 1
# Created a chunk of size 240, which is longer than the specified 1
# Created a chunk of size 257, which is longer than the specified 1
# Created a chunk of size 1436, which is longer than the specified 1
# Created a chunk of size 492, which is longer than the specified 1
# Created a chunk of size 272, which is longer than the specified 1
# Created a chunk of size 376, which is longer than the specified 1
# Created a chunk of size 385, which is longer than the specified 1
# Created a chunk of size 797, which is longer than the specified 1
# Created a chunk of size 210, which is longer than the specified 1
# Created a chunk of size 222, which is longer than the specified 1
# Created a chunk of size 799, which is longer than the specified 1
# Created a chunk of size 197, which is longer than the specified 1
# Created a chunk of size 226, which is longer than the specified 1
# Created a chunk of size 422, which is longer than the specified 1
# Created a chunk of size 800, which is longer than the specified 1
# Created a chunk of size 1354, which is longer than the specified 1
# Created a chunk of size 242, which is longer than the specified 1
# Created a chunk of size 837, which is longer than the specified 1
# Created a chunk of size 210, which is longer than the specified 1
# Created a chunk of size 234, which is longer than the specified 1
# Created a chunk of size 664, which is longer than the specified 1
# Created a chunk of size 278, which is longer than the specified 1
# Created a chunk of size 431, which is longer than the specified 1
# Created a chunk of size 951, which is longer than the specified 1
# Created a chunk of size 197, which is longer than the specified 1
# Created a chunk of size 218, which is longer than the specified 1
# Created a chunk of size 279, which is longer than the specified 1
# Created a chunk of size 637, which is longer than the specified 1
# Created a chunk of size 465, which is longer than the specified 1
# Created a chunk of size 286, which is longer than the specified 1
# Created a chunk of size 189, which is longer than the specified 1
# Created a chunk of size 226, which is longer than the specified 1
# Created a chunk of size 266, which is longer than the specified 1
# Created a chunk of size 199, which is longer than the specified 1
# Created a chunk of size 509, which is longer than the specified 1
# ...
# Created a chunk of size 848, which is longer than the specified 1
# Created a chunk of size 1127, which is longer than the specified 1
# Created a chunk of size 2032, which is longer than the specified 1
# Created a chunk of size 418, which is longer than the specified 1
# Created a chunk of size 189, which is longer than the specified 1
# Created a chunk of size 299, which is longer than the specified 1
# Created a chunk of size 1165, which is longer than the specified 1
# Created a chunk of size 166, which is longer than the specified 1
# Created a chunk of size 280, which is longer than the specified 1
# Created a chunk of size 438, which is longer than the specified 1
# Created a chunk of size 437, which is longer than the specified 1
# Created a chunk of size 290, which is longer than the specified 1
# Created a chunk of size 251, which is longer than the specified 1
# Created a chunk of size 923, which is longer than the specified 1
# Created a chunk of size 240, which is longer than the specified 1
# Created a chunk of size 188, which is longer than the specified 1
# Created a chunk of size 1005, which is longer than the specified 1
# Created a chunk of size 219, which is longer than the specified 1
# Created a chunk of size 232, which is longer than the specified 1
# Created a chunk of size 559, which is longer than the specified 1
# Created a chunk of size 185, which is longer than the specified 1
# Created a chunk of size 295, which is longer than the specified 1
# Created a chunk of size 373, which is longer than the specified 1
# Created a chunk of size 1109, which is longer than the specified 1
# Created a chunk of size 1640, which is longer than the specified 1
# Created a chunk of size 903, which is longer than the specified 1
# Created a chunk of size 476, which is longer than the specified 1
# Created a chunk of size 344, which is longer than the specified 1
# Created a chunk of size 1763, which is longer than the specified 1
# Created a chunk of size 890, which is longer than the specified 1
# Created a chunk of size 1193, which is longer than the specified 1
# Created a chunk of size 2141, which is longer than the specified 1
# Created a chunk of size 208, which is longer than the specified 1
# Created a chunk of size 322, which is longer than the specified 1
# Created a chunk of size 616, which is longer than the specified 1
# Created a chunk of size 229, which is longer than the specified 1
# Created a chunk of size 323, which is longer than the specified 1
# Created a chunk of size 196, which is longer than the specified 1
# Created a chunk of size 1157, which is longer than the specified 1
# Created a chunk of size 1302, which is longer than the specified 1
# Created a chunk of size 194, which is longer than the specified 1
# Created a chunk of size 188, which is longer than the specified 1
# Created a chunk of size 167, which is longer than the specified 1
# Created a chunk of size 624, which is longer than the specified 1
# Created a chunk of size 269, which is longer than the specified 1
# Created a chunk of size 148, which is longer than the specified 1
# Created a chunk of size 249, which is longer than the specified 1
# Created a chunk of size 1437, which is longer than the specified 1
# Created a chunk of size 258, which is longer than the specified 1
# Created a chunk of size 293, which is longer than the specified 1
# Created a chunk of size 255, which is longer than the specified 1
# Created a chunk of size 343, which is longer than the specified 1
# Created a chunk of size 206, which is longer than the specified 1
# Created a chunk of size 2372, which is longer than the specified 1
# Created a chunk of size 792, which is longer than the specified 1
# Created a chunk of size 741, which is longer than the specified 1
# Created a chunk of size 285, which is longer than the specified 1
# Created a chunk of size 883, which is longer than the specified 1
# Created a chunk of size 847, which is longer than the specified 1
# Created a chunk of size 251, which is longer than the specified 1
# Created a chunk of size 718, which is longer than the specified 1
# Created a chunk of size 219, which is longer than the specified 1
# Created a chunk of size 285, which is longer than the specified 1
# Created a chunk of size 253, which is longer than the specified 1
# Created a chunk of size 217, which is longer than the specified 1
# Created a chunk of size 202, which is longer than the specified 1
# Created a chunk of size 332, which is longer than the specified 1
# Created a chunk of size 152, which is longer than the specified 1
# Created a chunk of size 200, which is longer than the specified 1
# Created a chunk of size 829, which is longer than the specified 1
# Created a chunk of size 283, which is longer than the specified 1
# Created a chunk of size 209, which is longer than the specified 1
# Created a chunk of size 414, which is longer than the specified 1
# Created a chunk of size 228, which is longer than the specified 1
# Created a chunk of size 249, which is longer than the specified 1
# Created a chunk of size 368, which is longer than the specified 1
# Created a chunk of size 344, which is longer than the specified 1
# Created a chunk of size 250, which is longer than the specified 1
# Created a chunk of size 352, which is longer than the specified 1
# Created a chunk of size 179, which is longer than the specified 1
# Created a chunk of size 267, which is longer than the specified 1
# Created a chunk of size 1112, which is longer than the specified 1
# Created a chunk of size 191, which is longer than the specified 1
# Created a chunk of size 594, which is longer than the specified 1
# Created a chunk of size 184, which is longer than the specified 1
# Created a chunk of size 491, which is longer than the specified 1
# Created a chunk of size 236, which is longer than the specified 1
# Created a chunk of size 289, which is longer than the specified 1
# Created a chunk of size 774, which is longer than the specified 1
# Created a chunk of size 211, which is longer than the specified 1
# Created a chunk of size 1143, which is longer than the specified 1
# Created a chunk of size 217, which is longer than the specified 1
# Created a chunk of size 977, which is longer than the specified 1
# Created a chunk of size 202, which is longer than the specified 1
# Created a chunk of size 184, which is longer than the specified 1
# Created a chunk of size 366, which is longer than the specified 1
# Created a chunk of size 179, which is longer than the specified 1
# Created a chunk of size 251, which is longer than the specified 1
# Created a chunk of size 234, which is longer than the specified 1
# Created a chunk of size 317, which is longer than the specified 1
# Created a chunk of size 1323, which is longer than the specified 1
# Created a chunk of size 363, which is longer than the specified 1
# Created a chunk of size 882, which is longer than the specified 1
# Created a chunk of size 464, which is longer than the specified 1
# Created a chunk of size 309, which is longer than the specified 1
# Created a chunk of size 231, which is longer than the specified 1
# Created a chunk of size 740, which is longer than the specified 1
# Created a chunk of size 202, which is longer than the specified 1
# Created a chunk of size 608, which is longer than the specified 1
# Created a chunk of size 209, which is longer than the specified 1
# Created a chunk of size 248, which is longer than the specified 1
# Created a chunk of size 285, which is longer than the specified 1
# Created a chunk of size 238, which is longer than the specified 1
# Created a chunk of size 517, which is longer than the specified 1
# Created a chunk of size 270, which is longer than the specified 1
# Created a chunk of size 339, which is longer than the specified 1
# Created a chunk of size 232, which is longer than the specified 1
# Created a chunk of size 255, which is longer than the specified 1
# Created a chunk of size 196, which is longer than the specified 1
# Created a chunk of size 259, which is longer than the specified 1
# Created a chunk of size 967, which is longer than the specified 1
# Created a chunk of size 176, which is longer than the specified 1
# Created a chunk of size 243, which is longer than the specified 1
# Created a chunk of size 250, which is longer than the specified 1
# Created a chunk of size 245, which is longer than the specified 1
# Created a chunk of size 1307, which is longer than the specified 1
# Created a chunk of size 213, which is longer than the specified 1
# Created a chunk of size 1146, which is longer than the specified 1
# Created a chunk of size 1119, which is longer than the specified 1
# Created a chunk of size 169, which is longer than the specified 1
# Created a chunk of size 246, which is longer than the specified 1
# Created a chunk of size 1292, which is longer than the specified 1
# Created a chunk of size 452, which is longer than the specified 1
# Created a chunk of size 234, which is longer than the specified 1
# Created a chunk of size 774, which is longer than the specified 1
# Created a chunk of size 224, which is longer than the specified 1
# Created a chunk of size 762, which is longer than the specified 1
# Created a chunk of size 172, which is longer than the specified 1
# Created a chunk of size 245, which is longer than the specified 1
# Created a chunk of size 267, which is longer than the specified 1
# Created a chunk of size 840, which is longer than the specified 1
# Created a chunk of size 243, which is longer than the specified 1
# Created a chunk of size 535, which is longer than the specified 1
# Created a chunk of size 418, which is longer than the specified 1
# Created a chunk of size 239, which is longer than the specified 1
# Created a chunk of size 193, which is longer than the specified 1
# Created a chunk of size 187, which is longer than the specified 1
# Created a chunk of size 343, which is longer than the specified 1
# Created a chunk of size 199, which is longer than the specified 1
# Created a chunk of size 177, which is longer than the specified 1
# Created a chunk of size 169, which is longer than the specified 1
# Created a chunk of size 190, which is longer than the specified 1
# Created a chunk of size 187, which is longer than the specified 1
# Created a chunk of size 257, which is longer than the specified 1
# Created a chunk of size 440, which is longer than the specified 1
# Created a chunk of size 191, which is longer than the specified 1
# Created a chunk of size 407, which is longer than the specified 1
# Created a chunk of size 339, which is longer than the specified 1
# Created a chunk of size 269, which is longer than the specified 1
# Created a chunk of size 226, which is longer than the specified 1
# Created a chunk of size 263, which is longer than the specified 1
# Created a chunk of size 220, which is longer than the specified 1
# Created a chunk of size 460, which is longer than the specified 1
# Created a chunk of size 499, which is longer than the specified 1
# Created a chunk of size 188, which is longer than the specified 1
# Created a chunk of size 176, which is longer than the specified 1
# Created a chunk of size 1530, which is longer than the specified 1
# Created a chunk of size 325, which is longer than the specified 1
# Created a chunk of size 163, which is longer than the specified 1
# Created a chunk of size 576, which is longer than the specified 1
# Created a chunk of size 183, which is longer than the specified 1
# Created a chunk of size 892, which is longer than the specified 1
# Created a chunk of size 326, which is longer than the specified 1
# Created a chunk of size 257, which is longer than the specified 1
# Created a chunk of size 379, which is longer than the specified 1
# Created a chunk of size 2149, which is longer than the specified 1
# Created a chunk of size 254, which is longer than the specified 1
# Created a chunk of size 310, which is longer than the specified 1
# Created a chunk of size 204, which is longer than the specified 1
# Created a chunk of size 354, which is longer than the specified 1
# Created a chunk of size 325, which is longer than the specified 1
# Created a chunk of size 469, which is longer than the specified 1
# Created a chunk of size 288, which is longer than the specified 1
# Created a chunk of size 677, which is longer than the specified 1
# Created a chunk of size 1024, which is longer than the specified 1
# Created a chunk of size 818, which is longer than the specified 1
# Created a chunk of size 162, which is longer than the specified 1
# Created a chunk of size 229, which is longer than the specified 1
# Created a chunk of size 243, which is longer than the specified 1
# Created a chunk of size 268, which is longer than the specified 1
# Created a chunk of size 345, which is longer than the specified 1
# Created a chunk of size 308, which is longer than the specified 1
# Created a chunk of size 351, which is longer than the specified 1
# Created a chunk of size 1059, which is longer than the specified 1
# Created a chunk of size 415, which is longer than the specified 1
# Created a chunk of size 233, which is longer than the specified 1
# Created a chunk of size 301, which is longer than the specified 1
# Created a chunk of size 918, which is longer than the specified 1
# Created a chunk of size 167, which is longer than the specified 1
# Created a chunk of size 694, which is longer than the specified 1
# Created a chunk of size 239, which is longer than the specified 1
# Created a chunk of size 1034, which is longer than the specified 1
# Created a chunk of size 683, which is longer than the specified 1
# Created a chunk of size 184, which is longer than the specified 1
# Created a chunk of size 168, which is longer than the specified 1
# Created a chunk of size 770, which is longer than the specified 1
# Created a chunk of size 307, which is longer than the specified 1
# Created a chunk of size 259, which is longer than the specified 1
# Created a chunk of size 2209, which is longer than the specified 1
# Created a chunk of size 988, which is longer than the specified 1
# Created a chunk of size 549, which is longer than the specified 1
# Created a chunk of size 1119, which is longer than the specified 1
# Created a chunk of size 200, which is longer than the specified 1
# Created a chunk of size 895, which is longer than the specified 1
# Created a chunk of size 319, which is longer than the specified 1
# Created a chunk of size 575, which is longer than the specified 1
# Created a chunk of size 894, which is longer than the specified 1
# Created a chunk of size 175, which is longer than the specified 1
# Created a chunk of size 213, which is longer than the specified 1
# Created a chunk of size 247, which is longer than the specified 1
# Created a chunk of size 652, which is longer than the specified 1
# Created a chunk of size 930, which is longer than the specified 1
# Created a chunk of size 216, which is longer than the specified 1
# Created a chunk of size 175, which is longer than the specified 1
# Created a chunk of size 203, which is longer than the specified 1
# Created a chunk of size 243, which is longer than the specified 1
# Created a chunk of size 206, which is longer than the specified 1
# Created a chunk of size 256, which is longer than the specified 1
# Created a chunk of size 195, which is longer than the specified 1
# Created a chunk of size 168, which is longer than the specified 1
# Created a chunk of size 1003, which is longer than the specified 1
# Created a chunk of size 288, which is longer than the specified 1
# Created a chunk of size 254, which is longer than the specified 1
# Created a chunk of size 292, which is longer than the specified 1
# Created a chunk of size 1255, which is longer than the specified 1
# Created a chunk of size 368, which is longer than the specified 1
# Created a chunk of size 250, which is longer than the specified 1
# Created a chunk of size 232, which is longer than the specified 1
# Created a chunk of size 400, which is longer than the specified 1
# Created a chunk of size 237, which is longer than the specified 1
# Created a chunk of size 749, which is longer than the specified 1

# %%
documents[0]
# Out:
# Document(metadata={'source': 'C:\\Users\\Ananya\\OneDrive\\Onedrive\\Desktop\\2025 Files\\Semester 2\\Machine Learning\\Book-Recommendation\\tagged_description.txt'}, page_content='"9780313309335 Wherever vampires existed in the imaginations of different peoples, they adapted themselves to the customs of the local culture. In The Vampyre (1819), John Polidori introduced Lord Ruthven and established the vampire craze of the 19th century that resulted in a flood of German vampire poetry, French vampire drama, and British vampire fiction. That tradition culminated in Bram Stoker\'s Dracula (1897), which fixed the character of the Transylvanian nobleman firmly in the public imagination. The contributors to this volume examine representations of the vampire in fiction, film, folklore, and popular culture. While some look at Stoker and the early literary vampire, others study the works of contemporary writers, such as Anne Rice and Chelsea Quinn Yarbro, vampirism as a metaphor for AIDS, and racial issues in such films as Blacula and Vampire in Brooklyn."')

# %%
print("Current key:", os.getenv("OPENAI_API_KEY"))
# Out:
# Current key: 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

# %%
import dotenv
print(dotenv.dotenv_values())
# Out:
# OrderedDict({'OPENAI_API_KEY': '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', 'Huggingface_API_Token': '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'})

# %%
db_books = Chroma.from_documents(
    documents,
    embedding=OpenAIEmbeddings())

# %%
query = "A book to teach children about nature"
docs = db_books.similarity_search(query, k = 10)
docs
# Out:
# [Document(id='e0f1d53c-f7d8-4d1f-8969-ebdfb3786440', metadata={'source': 'C:\\Users\\Ananya\\OneDrive\\Onedrive\\Desktop\\2025 Files\\Semester 2\\Machine Learning\\Book-Recommendation\\tagged_description.txt'}, page_content='"9780786808069 Children will discover the exciting world of their own backyard in this introduction to familiar animals from cats and dogs to bugs and frogs. The combination of photographs, illustrations, and fun facts make this an accessible and delightful learning experience."'),
#  Document(id='ff157bf7-1528-4f1d-ae9c-36e52e43885c', metadata={'source': 'C:\\Users\\Ananya\\OneDrive\\Onedrive\\Desktop\\2025 Files\\Semester 2\\Machine Learning\\Book-Recommendation\\tagged_description.txt'}, page_content='"9780786808380 Introduce your babies to birds, cats, dogs, and babies through fine art, illustration, and photographs. These books are a rare opportunity to expose little ones to a range of images on a single subject, from simple child\'s drawings and abstract art to playful photos. A brief text accompanies each image, introducing the baby to some basic -- and sometimes playful -- information about the subjects."'),
#  Document(id='c51c333f-db1a-4ee6-9053-deaacf51135c', metadata={'source': 'C:\\Users\\Ananya\\OneDrive\\Onedrive\\Desktop\\2025 Files\\Semester 2\\Machine Learning\\Book-Recommendation\\tagged_description.txt'}, page_content='"9780786808397 Introduce your baby to birds, cats, dogs, and babies through fine art, illustration, and photographs. These books are a rare opportunity to exopse little ones to a range of images on a single subject, from simple child\'s drawings and abstract art to playful photos. A brief text accompanies each image, introducing baby to some basic -- and sometimes playful -- information about the subjects."'),
#  Document(id='4edc5863-aa4a-451b-a187-686b08430761', metadata={'source': 'C:\\Users\\Ananya\\OneDrive\\Onedrive\\Desktop\\2025 Files\\Semester 2\\Machine Learning\\Book-Recommendation\\tagged_description.txt'}, page_content='"9780689861130 Children will love joining in and imitating the animal noises and sounds in this big, bold board book format, illustrated with Sandra Boynton\'s seriously silly signature animals."'),
#  Document(id='50920263-c928-4da2-adc1-2b4dbfd8bbab', metadata={'source': 'C:\\Users\\Ananya\\OneDrive\\Onedrive\\Desktop\\2025 Files\\Semester 2\\Machine Learning\\Book-Recommendation\\tagged_description.txt'}, page_content='"9780067575208 First published more than three decades ago, this reissue of Rachel Carson\'s award-winning classic brings her unique vision to a new generation of readers. Stunning new photographs by Nick Kelsh beautifully complement Carson\'s intimate account of adventures with her young nephew, Roger, as they enjoy walks along the rocky coast of Maine and through dense forests and open fields, observing wildlife, strange plants, moonlight and storm clouds, and listening to the ""living music"" of insects in the underbrush. ""If a child is to keep alive his inborn sense of wonder."" Writes Carson, ""he needs the companionship of at least one adult who can share it, rediscovering with him the joy, excitement and mystery of the world we live in."" The Sense of Wonder is a refreshing antidote to indifference and a guide to capturing the simple power of discovery that Carson views as essential to life. In her insightful new introduction, Linda Lear remembers Rachel Carson\'s groundbreaking achievements in the context of the legendary environmentalist\'s personal commitment to introducing young and old to the miracles of nature. Kelsh\'s lush photographs inspire sensual, tactile reactions: masses of leaves floating in a puddle are just waiting to be scooped up and examined more closely. An image of a narrow path through the trees evokes the earthy scent of the woods after a summer rain. Close-ups of mosses and miniature lichen fantasy-lands will spark innocent\'as well as more jaded\'imaginations. Like a curious child studying things underfoot and within reach, Kelsh\'s camera is drawn to patterns in nature that too often elude hurried adults\'a stand of beech trees in the springtime, patches of melting snow and the ripples from a pebble tossed into a slow-moving stream. The Sense of Wonder is a timeless volume that will be passed on from children to grandchildren, as treasured as the memory of an early-morning walk when the song of a whippoorwill was heard as if for the first time."'),
#  Document(id='b88afbae-32e8-4b02-80cf-03c2db5d2f42', metadata={'source': 'C:\\Users\\Ananya\\OneDrive\\Onedrive\\Desktop\\2025 Files\\Semester 2\\Machine Learning\\Book-Recommendation\\tagged_description.txt'}, page_content="9780241003008 Eric Carle's children's classic is the story of a very small and very hungry caterpillar who manages to nibble his way through the pages of this enchanting book."),
#  Document(id='19d84bf0-5311-4624-86e6-3fa86d6f082a', metadata={'source': 'C:\\Users\\Ananya\\OneDrive\\Onedrive\\Desktop\\2025 Files\\Semester 2\\Machine Learning\\Book-Recommendation\\tagged_description.txt'}, page_content='"9780764122781 Titles in this series present basic information on reptiles plus specific instructions for their care. Each book opens with a description of the animal as it exists in its natural habitat, then continues with information on its life cycle and distribution in nature. Readers then get advice on selecting a good specimen, determining sex, and providing proper housing, feeding, and health care. Books are heavily illustrated with instructive color photos."'),
#  Document(id='61501b57-6217-44c4-9472-210998d5d6e5', metadata={'source': 'C:\\Users\\Ananya\\OneDrive\\Onedrive\\Desktop\\2025 Files\\Semester 2\\Machine Learning\\Book-Recommendation\\tagged_description.txt'}, page_content='9780440362050 A small boy finds excitement and promise in the daily life of his California valley during the early years of the twentieth century in this collection of short stories'),
#  Document(id='761c6d4e-3bd2-4d83-884e-defdb43468f5', metadata={'source': 'C:\\Users\\Ananya\\OneDrive\\Onedrive\\Desktop\\2025 Files\\Semester 2\\Machine Learning\\Book-Recommendation\\tagged_description.txt'}, page_content='"9780064434980 Even the youngest child can enjoy a special adaptation of a classic Little House tale, as Laura and Mary listen to Pa talk about meeting a mother deer and her baby fawn deep in the Big Woods of Wisconsin."'),
#  Document(id='d10336ad-16b7-4133-b6ff-4ba9b4bef528', metadata={'source': 'C:\\Users\\Ananya\\OneDrive\\Onedrive\\Desktop\\2025 Files\\Semester 2\\Machine Learning\\Book-Recommendation\\tagged_description.txt'}, page_content='"9780007105045 ""The two works \'On fairy-stories\' and \'Leaf by Niggle\' were first brought together to form the book \'Tree and leaf\' in 1964. In this new edition a third element is added: the poem Mythopoeia, the making of myths...""--Preface."')]

# %%
books[books["isbn13"] == int(docs[0].page_content.split()[0].strip())]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 books[books["isbn13"] == int(docs[0].page_content.split()[0].strip())]
#
# ValueError: invalid literal for int() with base 10: '"9780786808069'

# %%
def retrieve_semantic_recommendations(
        query: str,
        top_k: int = 10,
) -> pd.DataFrame:
    recs = db_books.similarity_search(query, k = 50)

    books_list = []

    for i in range(0, len(recs)):
        books_list += [int(recs[i].page_content.strip('"').split()[0])]

    return books[books["isbn13"].isin(books_list)]

# %%
retrieve_semantic_recommendations("literature" )
# Out:
#              isbn13      isbn10  \
# 7     9780472064847  0472064843
# 63    9780684848150  0684848155
# 107   9780812971064  081297106X
# 110   9780872206786  0872206785
# 157   9781932416480  193241648X
# 163   9780679765844  0679765840
# 260   9780553377767  0553377760
# 271   9780312424688  031242468X
# 284   9780060841867  0060841869
# 314   9781840224535  1840224533
# 419   9780312423131  0312423136
# 467   9780141183022  0141183020
# 539   9780679725404  0679725407
# 591   9781416500391  1416500391
# 621   9780802151803  0802151809
# 780   9780486424620  0486424626
# 781   9780826407078  0826407072
# 883   9780141183534  0141183535
# 909   9781563050756  1563050757
# 946   9780679767091  0679767096
# 953   9780802134905  0802134904
# 1028  9780316281331  0316281336
# 1036  9780156260558  0156260557
# 1116  9780393930139  0393930130
# 1193  9780451528308  0451528301
# 1213  9780156932509  0156932504
# 1255  9780060921712  0060921714
# 1257  9780099730514  0099730510
# 1308  9781567430288  1567430287
# 1338  9780872200470  0872200477
# 1342  9780618586455  0618586458
# 1584  9780199267170  0199267170
# 1605  9780060593247  0060593245
# 1693  9780156031639  0156031639
# 1747  9780571193783  0571193781
# 1823  9780024181909  0024181900
# 1868  9780486447780  0486447782
# 1873  9780299125400  0299125408
# 1892  9781400051533  1400051533
# 1951  9780141439907  0141439904
# 2026  9780156508872  0156508877
# 2047  9780060727635  0060727632
# 2054  9780486431680  0486431681
# 2389  9781565124820  1565124820
# 2417  9780520234413  0520234413
# 2423  9780192833600  019283360X
# 2467  9780143039938  0143039938
# 2477  9780374517885  0374517886
# 2575  9780393925722  0393925722
# 2583  9780571203123  0571203124
#
#                                                   title  \
# 7                                     Feminist Measures
# 63                                           Underworld
# 107                            Reading Lolita in Tehran
# 110                      Complete Poems and Major Prose
# 157                                         McSweeney's
# 163                                    The Simple Truth
# 260                    The Fairy Tales of Hermann Hesse
# 271                                     Collected Prose
# 284                                         The Curtain
# 314          The Death of Ivan Ilyich and Other Stories
# 419                                         Galatea 2.2
# 467                                            Sammlung
# 539                                                 Aké
# 591            Gulliver's Travels and A Modest Proposal
# 621                                               Sexus
# 780                     The Trojan Women and Hippolytus
# 781   Nathan the Wise, Minna von Barnhelm, and Other...
